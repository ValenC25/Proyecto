# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenC25/Proyecto-Risaralda-sin-Humo/blob/main/Proyecto_Risaralda_sin_Humo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ValenC25/Proyecto-Risaralda-sin-Humo
# Out:
# fatal: destination path 'Proyecto-Risaralda-sin-Humo' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np

file_path = '/content/Proyecto-Risaralda-sin-Humo/Numero_de_Veh_culos_El_ctricos_-_Hibridos_20250808.csv'
data = pd.read_csv(file_path)
data
# Out:
#       COMBUSTIBLE  ESTADO  MODELO          FECHA_REGISTRO  AÑO_REGISTRO  \
# 0       ELECTRICO  ACTIVO    2022  06/30/2022 12:00:00 AM          2022
# 1       ELECTRICO  ACTIVO    2023  10/21/2022 12:00:00 AM          2022
# 2       ELECTRICO  ACTIVO    2014  09/28/2015 12:00:00 AM          2015
# 3       ELECTRICO  ACTIVO    2021  08/10/2022 12:00:00 AM          2022
# 4       ELECTRICO  ACTIVO    2022  10/25/2021 12:00:00 AM          2021
# ...           ...     ...     ...                     ...           ...
# 56540   GASO ELEC  ACTIVO    2023  10/06/2022 12:00:00 AM          2022
# 56541   GASO ELEC  ACTIVO    2023  10/07/2022 12:00:00 AM          2022
# 56542   GASO ELEC  ACTIVO    2023  10/12/2022 12:00:00 AM          2022
# 56543   GASO ELEC  ACTIVO    2023  09/30/2022 12:00:00 AM          2022
# 56544   GASO ELEC  ACTIVO    2022  11/26/2022 12:00:00 AM          2022
#
#       CLASIFICACION        CLASE    SERVICIO     MARCA            LINEA  ...  \
# ...

# %%
import pandas as pd
import numpy as np

file_path1 = '/content/Proyecto-Risaralda-sin-Humo/Parque_Automotor_Registrado_en_el_Departamento_de_Risaralda_20250808.csv'
data1 = pd.read_csv(file_path1)
data1
# Out:
#               CLASE   PLACA      MARCA  MODELO            LINEA  CILINDRAJE
# 0         CAMIONETA  LXU283     NISSAN    2024      X-TRAIL T33        1497
# 1         AUTOMOVIL  PEL456    RENAULT    1997          CLIO RN        1400
# 2       MOTOCICLETA  GMP67G   KAWASAKI    2022          KLE300C         296
# 3       MOTOCICLETA  QOO95G    VICTORY    2025  NEW LIFE 125 TK         124
# 4       MOTOCICLETA  GLD96G     SUZUKI    2023            DR150         149
# ...             ...     ...        ...     ...              ...         ...
# 420917  MOTOCICLETA  UVI89G      HONDA    2024           CB190R         184
# 420918    AUTOMOVIL  CGT076      MAZDA    1989           323 HB        1300
# 420919    CAMIONETA  KVS789     TOYOTA    2023         FORTUNER        2393
# 420920    AUTOMOVIL  MWL781    CITROEN    2013  C3 16I BVA SXPK        1600
# 420921    AUTOMOVIL  RCR584  CHEVROLET    2011            SPARK        1206
#
# [420922 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56545 entries, 0 to 56544
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   COMBUSTIBLE          56545 non-null  object
#  1   ESTADO               56545 non-null  object
#  2   MODELO               56545 non-null  int64
#  3   FECHA_REGISTRO       56545 non-null  object
#  4   AÑO_REGISTRO         56545 non-null  int64
#  5   CLASIFICACION        56545 non-null  object
#  6   CLASE                56545 non-null  object
#  7   SERVICIO             56545 non-null  object
#  8   MARCA                56545 non-null  object
#  9   LINEA                56545 non-null  object
#  10  CARROCERIA           56545 non-null  object
#  11  CILINDRAJE           53054 non-null  float64
#  12  MODALIDAD            36663 non-null  object
#  13  ORGANISMO_TRANSITO   56545 non-null  object
#  14  MUNICIPIO            56545 non-null  object
# ...

# %%
grupos = data.groupby('DEPARTAMENTO')
datos_risaralda = grupos.get_group('Risaralda')
datos_risaralda
# Out:
#       COMBUSTIBLE  ESTADO  MODELO          FECHA_REGISTRO  AÑO_REGISTRO  \
# 1       ELECTRICO  ACTIVO    2023  10/21/2022 12:00:00 AM          2022
# 164     ELECTRICO  ACTIVO    2021  12/29/2020 12:00:00 AM          2020
# 191     ELECTRICO  ACTIVO    2022  08/29/2022 12:00:00 AM          2022
# 219     ELECTRICO  ACTIVO    2020  12/29/2020 12:00:00 AM          2020
# 455     ELECTRICO  ACTIVO    2022  05/04/2022 12:00:00 AM          2022
# ...           ...     ...     ...                     ...           ...
# 56321   GASO ELEC  ACTIVO    2022  11/01/2022 12:00:00 AM          2022
# 56400   GASO ELEC  ACTIVO    2023  10/12/2022 12:00:00 AM          2022
# 56401   GASO ELEC  ACTIVO    2023  10/12/2022 12:00:00 AM          2022
# 56402   GASO ELEC  ACTIVO    2023  10/05/2022 12:00:00 AM          2022
# 56403   GASO ELEC  ACTIVO    2023  10/05/2022 12:00:00 AM          2022
#
#       CLASIFICACION        CLASE    SERVICIO       MARCA             LINEA  \
# ...
